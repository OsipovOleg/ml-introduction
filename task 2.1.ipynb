# %%
# ОТРЕНДЕРЕНО НА КАГЛЕ, ЛОКАЛЬНО МОЖЕТ НЕ РАБОТАТЬ
# %pip install folium

# %%
import folium

m = folium.Map(location=(55.7522200, 37.6155600), zoom_start=10)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style="darkgrid")

# %% [markdown]
# Часть 0

# %%
from google.colab import drive
drive.mount("/content/drive")
df = pd.read_csv('/content/drive/MyDrive/train.csv')
# Out:
# Mounted at /content/drive

# %%
df
# Out:
#                 id  vendor_id  ... store_and_fwd_flag trip_duration
# 0        id2875421          2  ...                  N           455
# 1        id2377394          1  ...                  N           663
# 2        id3858529          2  ...                  N          2124
# 3        id3504673          2  ...                  N           429
# 4        id2181028          2  ...                  N           435
# ...            ...        ...  ...                ...           ...
# 1458639  id2376096          2  ...                  N           778
# 1458640  id1049543          1  ...                  N           655
# 1458641  id2304944          2  ...                  N           764
# 1458642  id2714485          1  ...                  N           373
# 1458643  id1209952          1  ...                  N           198
#
# [1458644 rows x 11 columns]

# %%
if 'dropoff_datetime' in df:
   del df['dropoff_datetime']

# %%
df
# Out:
#                 id  vendor_id  ... store_and_fwd_flag  trip_duration
# 0        id2875421          2  ...                  N            455
# 1        id2377394          1  ...                  N            663
# 2        id3858529          2  ...                  N           2124
# 3        id3504673          2  ...                  N            429
# 4        id2181028          2  ...                  N            435
# ...            ...        ...  ...                ...            ...
# 1458639  id2376096          2  ...                  N            778
# 1458640  id1049543          1  ...                  N            655
# 1458641  id2304944          2  ...                  N            764
# 1458642  id2714485          1  ...                  N            373
# 1458643  id1209952          1  ...                  N            198
#
# [1458644 rows x 10 columns]

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])

# %%
df
# Out:
#                 id  vendor_id  ... store_and_fwd_flag  trip_duration
# 0        id2875421          2  ...                  N            455
# 1        id2377394          1  ...                  N            663
# 2        id3858529          2  ...                  N           2124
# 3        id3504673          2  ...                  N            429
# 4        id2181028          2  ...                  N            435
# ...            ...        ...  ...                ...            ...
# 1458639  id2376096          2  ...                  N            778
# 1458640  id1049543          1  ...                  N            655
# 1458641  id2304944          2  ...                  N            764
# 1458642  id2714485          1  ...                  N            373
# 1458643  id1209952          1  ...                  N            198
#
# [1458644 rows x 10 columns]

# %%
df.groupby('trip_duration')['trip_duration'].count().hist()

# %% [markdown]
# выброс 0-200

# %%
df['log_trip_duration'] = np.log1p(df['trip_duration'])

# %%
df
# Out:
#                 id  vendor_id  ... trip_duration  log_trip_duration
# 0        id2875421          2  ...           455           6.122493
# 1        id2377394          1  ...           663           6.498282
# 2        id3858529          2  ...          2124           7.661527
# 3        id3504673          2  ...           429           6.063785
# 4        id2181028          2  ...           435           6.077642
# ...            ...        ...  ...           ...                ...
# 1458639  id2376096          2  ...           778           6.658011
# 1458640  id1049543          1  ...           655           6.486161
# 1458641  id2304944          2  ...           764           6.639876
# 1458642  id2714485          1  ...           373           5.924256
# 1458643  id1209952          1  ...           198           5.293305
#
# [1458644 rows x 11 columns]

# %%
df.groupby('log_trip_duration')['log_trip_duration'].count().hist()

# %%
from sklearn.metrics import mean_squared_error

# %%
#нечто

# %%
df
# Out:
#                 id  vendor_id  ... trip_duration  log_trip_duration
# 0        id2875421          2  ...           455           6.122493
# 1        id2377394          1  ...           663           6.498282
# 2        id3858529          2  ...          2124           7.661527
# 3        id3504673          2  ...           429           6.063785
# 4        id2181028          2  ...           435           6.077642
# ...            ...        ...  ...           ...                ...
# 1458639  id2376096          2  ...           778           6.658011
# 1458640  id1049543          1  ...           655           6.486161
# 1458641  id2304944          2  ...           764           6.639876
# 1458642  id2714485          1  ...           373           5.924256
# 1458643  id1209952          1  ...           198           5.293305
#
# [1458644 rows x 11 columns]

# %%
if 'trip_duration' in df:
   del df['trip_duration']

# %%
df
# Out:
#                 id  vendor_id  ... store_and_fwd_flag  log_trip_duration
# 0        id2875421          2  ...                  N           6.122493
# 1        id2377394          1  ...                  N           6.498282
# 2        id3858529          2  ...                  N           7.661527
# 3        id3504673          2  ...                  N           6.063785
# 4        id2181028          2  ...                  N           6.077642
# ...            ...        ...  ...                ...                ...
# 1458639  id2376096          2  ...                  N           6.658011
# 1458640  id1049543          1  ...                  N           6.486161
# 1458641  id2304944          2  ...                  N           6.639876
# 1458642  id2714485          1  ...                  N           5.924256
# 1458643  id1209952          1  ...                  N           5.293305
#
# [1458644 rows x 10 columns]

# %% [markdown]
# Часть 1

# %% [markdown]
# Задание 2 (0.25 баллов).

# %%
df1 = df.groupby([df['pickup_datetime'].dt.date]).count()

# %%
df1
# Out:
#                    id  vendor_id  ...  store_and_fwd_flag  log_trip_duration
# pickup_datetime                   ...
# 2016-01-01       7162       7162  ...                7162               7162
# 2016-01-02       6512       6512  ...                6512               6512
# 2016-01-03       6353       6353  ...                6353               6353
# 2016-01-04       6725       6725  ...                6725               6725
# 2016-01-05       7204       7204  ...                7204               7204
# ...               ...        ...  ...                 ...                ...
# 2016-06-26       7084       7084  ...                7084               7084
# 2016-06-27       7311       7311  ...                7311               7311
# 2016-06-28       7253       7253  ...                7253               7253
# 2016-06-29       7623       7623  ...                7623               7623
# 2016-06-30       7588       7588  ...                7588               7588
#
# ...

# %%
plt.figure(figsize=(15,30))
sns.countplot(y = df['pickup_datetime'].dt.dayofyear)

# %%
df.groupby([df['pickup_datetime'].dt.date])['pickup_datetime'].count().plot()

# %%
week_df = df.groupby(df['pickup_datetime'].dt.dayofweek).count().plot()

# %%
time_df = df.groupby(df['pickup_datetime'].dt.time).count().plot()

# %% [markdown]
# Задание 3 (0.5 баллов).

# %%
df['month'] = df['pickup_datetime'].dt.month

# %%
df['hour'] = df['pickup_datetime'].dt.hour

# %%
df2 = df.groupby(['month', 'hour']).size().to_frame()

# %%
df2
# Out:
#                 0
# month hour
# 1     0      8330
#       1      6400
#       2      4830
#       3      3574
#       4      2612
# ...           ...
# 6     19    14187
#       20    12799
#       21    13740
#       22    13391
#       23    11899
#
# [144 rows x 1 columns]

# %% [markdown]
# На семинаре мы рассматривали несколько моделей линейной регрессии в sklearn, но каждая из них оптимизировала среднеквадратичную ошибку (MSE), а не RMSLE. Давайте проделаем следующий трюк: будем предсказывать не целевую переменную, а ее логарифм. Обозначим $\hat{y}_i = \log{(y_i + 1)}$ — модифицированный таргет, а $\hat{a}(x_i)$ — предсказание модели, которая обучалась на $\hat{y}_i$, то есть логарифм таргета. Чтобы предсказать исходное значение, мы можем просто взять экспоненту от нашего предсказания: $a(x_i) = \exp(\hat{a}(x_i)) - 1$.

# %%
sns.relplot(data=df2, y=0, x='hour', hue='month');
